# %% [markdown]
#  ## Chapter 12, 13 Practice Problem

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('high_school_2019.csv')
df
# Out:
#                 지역                 학교명   1학년 학급수   1학년 학생수   2학년 학급수  \
# 0        서울특별시 강남구            국립국악고등학교         5       150         5
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교         8       239         8
# 2        서울특별시 금천구          국립전통예술고등학교         6       182         6
# 3        서울특별시 송파구              가락고등학교        11       282        11
# 4        서울특별시 강동구              강동고등학교         8       210         8
# ...            ...                 ...       ...       ...       ...
# 2393   제주특별자치도 제주시              제주고등학교        11       279        11
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교         8       151         8
# 2395  제주특별자치도 서귀포시              성산고등학교         4        76         5
# 2396   제주특별자치도 제주시           제주외국어고등학교         4        99         4
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교         5       116         5
#
#        2학년 학생수   3학년 학급수   3학년 학생수
# 0          149         5       143
# 1          228         8       270
# ...

# %%
df[' 1학년 학생수']
# Out:
# 0       150
# 1       239
# 2       182
# 3       282
# 4       210
#        ...
# 2393    279
# 2394    151
# 2395     76
# 2396     99
# 2397    116
# Name:  1학년 학생수, Length: 2398, dtype: int64

# %%
sum1 = df[' 1학년 학생수'] + df[' 2학년 학생수'] + df[' 3학년 학생수']

# %%
sum1
# Out:
# 0       442
# 1       737
# 2       525
# 3       832
# 4       614
#        ...
# 2393    863
# 2394    427
# 2395    270
# 2396    286
# 2397    340
# Length: 2398, dtype: int64

# %%
df['총 학생수'] = sum1

# %%
#13.3
df
# Out:
#                 지역                 학교명   1학년 학급수   1학년 학생수   2학년 학급수  \
# 0        서울특별시 강남구            국립국악고등학교         5       150         5
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교         8       239         8
# 2        서울특별시 금천구          국립전통예술고등학교         6       182         6
# 3        서울특별시 송파구              가락고등학교        11       282        11
# 4        서울특별시 강동구              강동고등학교         8       210         8
# ...            ...                 ...       ...       ...       ...
# 2393   제주특별자치도 제주시              제주고등학교        11       279        11
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교         8       151         8
# 2395  제주특별자치도 서귀포시              성산고등학교         4        76         5
# 2396   제주특별자치도 제주시           제주외국어고등학교         4        99         4
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교         5       116         5
#
#        2학년 학생수   3학년 학급수   3학년 학생수  총 학생수
# 0          149         5       143    442
# 1          228         8       270    737
# ...

# %%
df2 = df.sum(axis=0)
df2
# Out:
# 지역          서울특별시 강남구서울특별시 성북구서울특별시 금천구서울특별시 송파구서울특별시 강동구서...
#  학교명        국립국악고등학교서울대학교사범대학부설고등학교국립전통예술고등학교가락고등학교강동고등학교강...
#  1학년 학급수                                                18580
#  1학년 학생수                                               463400
#  2학년 학급수                                                18569
#  2학년 학생수                                               444714
#  3학년 학급수                                                18939
#  3학년 학생수                                               500698
# 총 학생수                                                 1408812
# dtype: object

# %%
df3 = df
df3[' 1학년 총 학생수'] = df2[' 1학년 학생수']
df3
# Out:
#                 지역                 학교명   1학년 학급수   1학년 학생수   2학년 학급수  \
# 0        서울특별시 강남구            국립국악고등학교         5       150         5
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교         8       239         8
# 2        서울특별시 금천구          국립전통예술고등학교         6       182         6
# 3        서울특별시 송파구              가락고등학교        11       282        11
# 4        서울특별시 강동구              강동고등학교         8       210         8
# ...            ...                 ...       ...       ...       ...
# 2393   제주특별자치도 제주시              제주고등학교        11       279        11
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교         8       151         8
# 2395  제주특별자치도 서귀포시              성산고등학교         4        76         5
# 2396   제주특별자치도 제주시           제주외국어고등학교         4        99         4
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교         5       116         5
#
#        2학년 학생수   3학년 학급수   3학년 학생수  총 학생수   1학년 총 학생수
# 0          149         5       143    442      463400
# ...

# %%
total = {'1학년 총 학생수':[df2[' 1학년 학생수']],
        '2학년 총 학생수':[df2[' 2학년 학생수']],
        '3학년 총 학생수':[df2[' 3학년 학생수']]}
total
# Out:
# {'1학년 총 학생수': [463400], '2학년 총 학생수': [444714], '3학년 총 학생수': [500698]}

# %%
df4 = pd.DataFrame(total,
                 columns=['1학년 총 학생수', '2학년 총 학생수', '3학년 총 학생수'],
                 index = ['total'])
df4
# Out:
#        1학년 총 학생수  2학년 총 학생수  3학년 총 학생수
# total     463400     444714     500698

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
mpl.rc('font', family='Malgun Gothic')
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["font.size"] = 14

# %%
df4
# Out:
#        1학년 총 학생수  2학년 총 학생수  3학년 총 학생수
# total     463400     444714     500698

# %%
df4['1학년 총 학생수']
# Out:
# total    463400
# Name: 1학년 총 학생수, dtype: int64

# %%
s1 = int(df4['1학년 총 학생수'])
print(s1)
s2 = int(df4['2학년 총 학생수'])
print(s2)
s3 = int(df4['3학년 총 학생수'])
print(s3)
# Out:
# 463400
# 444714
# 500698

# %%
ts = []
ts = [s1, s2, s3]
ts
# Out:
# [463400, 444714, 500698]

# %%
#df4.values
# Out:
# array([[463400, 444714, 500698]], dtype=int64)

# %%
#x1 = df4.values
#x = x1[0][:1]
#print(x1[0][:1])
#x
# Out:
# [463400]
# array([463400], dtype=int64)

# %%
x = ts
x
# Out:
# [463400, 444714, 500698]

# %%
y = ['1학년', '2학년', '3학년']
y
# Out:
# ['1학년', '2학년', '3학년']

# %%
#13.4
print('1학년 총 학생수 : %i'%s1)
print('2학년 총 학생수 : %i'%s2)
print('3학년 총 학생수 : %i'%s3)
plt.bar(y,x)
plt.title("전국 고등학교 학년별 총 학생수")
plt.show()
# Out:
# 1학년 총 학생수 : 463400
# 2학년 총 학생수 : 444714
# 3학년 총 학생수 : 500698

# %%
# Chapter 14
df = pd.read_csv('population_age_2020.csv')
df
# Out:
#       지역      총인구수     0~9세   10~19세   20~29세   30~39세   40~49세   50~59세  \
# 0     서울   9736962   658355   813563  1455903  1505729  1563968  1539385
# 1     부산   3410925   241624   281120   434692   431911   518321   580966
# 2     대구   2432883   186623   234528   321487   303397   391997   428622
# 3     인천   2954955   239941   281097   405835   417708   490716   515758
# 4     광주   1456121   125396   162728   207554   191432   244903   234048
# 5     대전   1473125   120476   151861   212143   199106   242381   243526
# 6     울산   1145710   103399   115623   147745   158271   190698   211255
# 7     세종    343788    47454    40574    36273    61442    65714    42907
# 8    경기도  13265377  1178548  1347854  1769080  1917785  2299179  2205106
# 9    강원도   1539521   108694   141975   179813   169694   227950   269666
# 10  충청북도   1598599   128290   153119   198910   198768   243982   273857
# 11  충청남도   2120995   179808   206578   243748   276553   329789   340568
# ...

# %%
df2 = df['100세 이상']
df2
# Out:
# 0     6380
# 1     1807
# 2      694
# 3      908
# 4      405
# 5      339
# 6      160
# 7       55
# 8     4010
# 9      803
# 10     541
# 11     885
# 12     817
# 13     822
# 14     960
# 15     739
# 16     266
# Name: 100세 이상, dtype: int64

# %%
df['지역'][:1]
# Out:
# 0    서울
# Name: 지역, dtype: object

# %%
df3 = df['지역']
df3
# Out:
# 0       서울
# 1       부산
# 2       대구
# 3       인천
# 4       광주
# 5       대전
# 6       울산
# 7       세종
# 8      경기도
# 9      강원도
# 10    충청북도
# 11    충청남도
# 12    전라북도
# 13    전라남도
# 14    경상북도
# 15    경상남도
# 16     제주도
# Name: 지역, dtype: object

# %%
df4 = df['총인구수']
df4
# Out:
# 0      9736962
# 1      3410925
# 2      2432883
# 3      2954955
# 4      1456121
# 5      1473125
# 6      1145710
# 7       343788
# 8     13265377
# 9      1539521
# 10     1598599
# 11     2120995
# 12     1815112
# 13     1861894
# 14     2658956
# 15     3358828
# 16      670876
# Name: 총인구수, dtype: int64

# %%
#df4 = []
df5 = pd.DataFrame(df3)
#df4['지역'] = df3
df5['100세 이상'] = df2
df5['총 인구수'] = df4
df5
# Out:
#       지역  100세 이상     총 인구수
# 0     서울     6380   9736962
# 1     부산     1807   3410925
# 2     대구      694   2432883
# 3     인천      908   2954955
# 4     광주      405   1456121
# 5     대전      339   1473125
# 6     울산      160   1145710
# 7     세종       55    343788
# 8    경기도     4010  13265377
# 9    강원도      803   1539521
# 10  충청북도      541   1598599
# 11  충청남도      885   2120995
# 12  전라북도      817   1815112
# 13  전라남도      822   1861894
# 14  경상북도      960   2658956
# 15  경상남도      739   3358828
# 16   제주도      266    670876

# %%
df6 = df5.sort_values( by=['100세 이상'], axis=0,ascending=False)
df7 = df6
df7
# Out:
#       지역  100세 이상     총 인구수
# 0     서울     6380   9736962
# 8    경기도     4010  13265377
# 1     부산     1807   3410925
# 14  경상북도      960   2658956
# 3     인천      908   2954955
# 11  충청남도      885   2120995
# 13  전라남도      822   1861894
# 12  전라북도      817   1815112
# 9    강원도      803   1539521
# 15  경상남도      739   3358828
# 2     대구      694   2432883
# 10  충청북도      541   1598599
# 4     광주      405   1456121
# 5     대전      339   1473125
# 16   제주도      266    670876
# 6     울산      160   1145710
# 7     세종       55    343788

# %%
df6[''] = range(0,17)
df6
# Out:
#       지역  100세 이상     총 인구수
# 0     서울     6380   9736962   0
# 8    경기도     4010  13265377   1
# 1     부산     1807   3410925   2
# 14  경상북도      960   2658956   3
# 3     인천      908   2954955   4
# 11  충청남도      885   2120995   5
# 13  전라남도      822   1861894   6
# 12  전라북도      817   1815112   7
# 9    강원도      803   1539521   8
# 15  경상남도      739   3358828   9
# 2     대구      694   2432883  10
# 10  충청북도      541   1598599  11
# 4     광주      405   1456121  12
# 5     대전      339   1473125  13
# 16   제주도      266    670876  14
# 6     울산      160   1145710  15
# 7     세종       55    343788  16

# %%
df7 = df6.set_index('')
df7
# Out:
#       지역  100세 이상     총 인구수
#
# 0     서울     6380   9736962
# 1    경기도     4010  13265377
# 2     부산     1807   3410925
# 3   경상북도      960   2658956
# 4     인천      908   2954955
# 5   충청남도      885   2120995
# 6   전라남도      822   1861894
# 7   전라북도      817   1815112
# 8    강원도      803   1539521
# 9   경상남도      739   3358828
# 10    대구      694   2432883
# 11  충청북도      541   1598599
# 12    광주      405   1456121
# 13    대전      339   1473125
# 14   제주도      266    670876
# 15    울산      160   1145710
# 16    세종       55    343788
