# %% [markdown]
#  # pandas

# %%
ds = []
ds.appned(ans[ans['dataset'] == 'I'])
ds.appned(ans[ans['dataset'] == 'II'])
ds.appned(ans[ans['dataset'] == 'III'])
ds.appned(ans[ans['dataset'] == 'IV'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-cd626d1f6f44> in <module>
#       1 ds = []
# ----> 2 ds.appned(ans[ans['dataset'] == 'I'])
#       3 ds.appned(ans[ans['dataset'] == 'II'])
#       4 ds.appned(ans[ans['dataset'] == 'III'])
#       5 ds.appned(ans[ans['dataset'] == 'IV'])
#
# AttributeError: 'list' object has no attribute 'appned'

# %%
fig, axs = plt.subplots(2,2,figsize = (12,10))
for i in range(4):
    axs[i//2][i%2].plot(ds[i]['x'],ds[i]['y'],'o')
    axs[i//2][i%2].plot([0,20],[3,13],'r-',lw=2)
    axs[i//2][i%2].set(xlim=(0,20), ylim=(2,14)
    axs[i//2][i%2].set(xtiks=range(0,21,2),yticks=range())
# Out:
#   File "<ipython-input-3-01b29f2a7175>", line 6
#     axs[i//2][i%2].set(xtiks=range(0,21,2),yticks=range())
#       ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
ans = sns.load_dataset('anscombe')
iris = sns.load_dataset("iris")    # 붓꽃 데이터
sns.pairplot(iris, hue="species", markers=["o", "s", "D"])
plt.title("Iris Pair Plot, Hue로 꽃의 종을 시각화")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-47300b9b334e> in <module>
#       3 iris = sns.load_dataset("iris")    # 붓꽃 데이터
#       4 sns.pairplot(iris, hue="species", markers=["o", "s", "D"])
# ----> 5 plt.title("Iris Pair Plot, Hue로 꽃의 종을 시각화")
#       6 plt.show()
#
# NameError: name 'plt' is not defined
